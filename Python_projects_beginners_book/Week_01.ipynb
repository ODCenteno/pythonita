# %% [markdown]
# # Week 01

# %%
# this is python
print("Hello, buddy!")
# Out:
# Hello, buddy!

# %% [markdown]
# # Guessing Game

# %%
# Guessing game
from random import randint
from IPython.display import clear_output

guessed = False
number = randint(0, 100)
guesses = 0

while not guessed:
    ans = input("Try to guess the number I am thinking of! ")
    
    guesses += 1
    
    clear_output()
    
    if int(ans) == number:
        print("Congrats! You guessed it correctly.")
        # use tab twice to indent twice
        
        print(f"It took you {guesses} guesses!")
        break
        
    elif int(ans) > number:
        print("The number is lower than what you guessed.")
    elif int(ans) < number:
        print("The number is greater than what you guessed.")

# %%
/*reglas:
selectores
declaraciones
propiedades 
valor*/


/* Paleta de colores: 
Background . Oscuro: #222831
Background . Dark grey: #121212
Secciones . azul-gris: #30475e
Resaltado . rojo: #f05454
Letras . hueso: #e8e8e8
*/

body {
    font-family: 'Roboto', sans-serif; 
    /* Va a tratar de elegir la fuente Source Sans Pro, pero si por alguna razón no la puede encontrar/aplicar buscará
    cualquier fuente del sistema que tenga serifas y la aplicará */
    background-color: #222831;
    color: #e8e8e8;
}

/* 
Estamos aplicando la propiedad a 6 selectores diferentes
Si no pongo las comas, va a ser un selector descendiente h1>h2>h3>h4>h5>h6 */
h1, h2, h3, h4, h5, h6 {
    font-family: 'Fjalla One', sans-serif;
    font-weight: normal;
}

h1 {
    font-size: 40px;
    line-height: 1.5;
    letter-spacing: -.2px;
    color: white;
    margin: 0;
    /* font-size: 50px;
    line-height: 1.5em;
    text-transform: capitalize;
    letter-spacing: -0.2px;
    color: #e8e8e8;
    display: block;
    margin: 15px 15px; */
    /* text-decoration: dashed; */
}

h1 strong {
    color: #f05454;
}

h2 {
    color: #f05454;
    text-transform: uppercase;
    font-family: 'Roboto', sans-serif;
    font-weight: bold;
    font-size: 24px;
    margin-bottom: 40px;
  }
/* TIPOS DE FUENTES */

/* @import url('https://fonts.googleapis.com/css?family=Fjalla+One|Roboto|Source+Sans+Pro'); */
/*Primero importo las fuentes y despues las uso*/


.header {
    color: #e8e8e8;
    background-color: #1b2127;
    display: flex;
    height: 50px;
    align-items: center;
    justify-content: space-between;
}

.menu { /* .menu hereda de .header */
    height: inherit;
    align-items: baseline;
}

ol,
ul {
  margin: 0;
  padding: 0;
  list-style: none;
}
figure {
    margin: 0;
  }

.header ol { /* .header ol hereda de .menu */
    /* display: flex; */
    height: inherit;
}

.header ol li { /* .header ol li hereda de .header ol */
    height: inherit;
}

.header a { /* .header a hereda de .header ol li */
    color: white;
    text-decoration: none;
    height: inherit;
    display: flex;
    align-items: center;
    padding: 0 10px; 
}

.flexbox {
    display: flex;
    /* flex-wrap: nowrap; */
    flex-wrap: wrap;
    /* flex-direction: column; */
  }
  
.box {
    width: 50px;
    height: 50px;
    margin: 5px;
    border: 1px solid red;

    flex-shrink: 0;
}

.hero {
    height: 300px;
    /* background-image: url("https://picsum.photos/500?portrait"); */
    background-color: #30475e;
    /* background-size: 500px 300px;
    background-repeat: no-repeat;
    background-position: right ; */
    display: flex;
    align-items: center;
    justify-content: space-between;

}
.hero_pic {
    object-fit: cover;
}

.portafolio {
    background: #121212;
    padding: 20px;
}

.project {
    /* border-top: 10px solid red;
  border-right: 10px solid green;
  border-left: 10px solid orange;
  border-bottom: 10px solid pink; */
  /* color: blue; */
  /* border-top-color: red;
  border-top-width: 15px;
  border-top-style: solid; */
  border: 1px solid gray;
  border-radius: 10px;
  /* border-top-left-radius: 50px;
  border-top-right-radius: 10px;
  border-bottom-left-radius: 10px;
  border-bottom-right-radius: 10px; */
  /* margin: 10px; */
  margin-bottom: 15px;
  /* margin-right
  margin-left 
  margin-top */
  padding: 20px;
  background: #30475e;
  display: flex;
  align-items: center;
  justify-content: space-between;
}

.project_h3 {

}
.project_course,
.project_date,
.project_url {
  margin: 10px 0;
}
.project_description {
  font-size: 20px;
}
.project strong {
  font-family: 'Fjalla One', sans-serif;
}
.project_details {
    width: 500px;
}
.project_image_container {
    width: 500px;
}
  
  .footer {
    color: white;
    background-color: #1b2127;
    display: flex;
    align-items: center;
    justify-content: space-between;
    font-size: x-small;
  }
  
  .footer img {
    vertical-align: middle;
  }
  
  .footer a {
    color: white;
  }

  .contact {
    background-color: #056fff;
    color: white;
    height: 150px;
    display: flex;
    align-items: center;
    justify-content: space-between;
  }
  
  .social {
  }
  
  .social-link {
    display: inline-block;
    width: 50px;
    height: 50px;
    margin: 0 10px;
    background-size: 50px 50px;
  }
  
  .social-link.twitter {
    background-image: url('../images/twitter.svg');
  }
  .social-link.facebook {
    background-image: url('../images/facebook.svg');
  }
  .social-link.github {
    background-image: url('../images/github.svg');
  }
  .social-link.instagram {
    background-image: url('../images/instagram.svg');
  }
  
  
  .form-email input {
    border-color: gray;
    border-style: solid;
    border-radius: 5px;
    padding: 10px 20px 10px 25px;
    background-image: url('../images/envelope.svg');
    background-size: 15px 15px;
    background-repeat: no-repeat;
    background-position-y: center;
    background-position-x: 5px;
  }
  
  .form-email button {
    display: block;
    background: transparent;
    color: white;
    padding: 10px 0;
    border-radius: 5px;
    width: 100px;
    margin-top: 10px;
  }
  
  .form-email h3 { 
    font-family: 'Source Sans Pro', sans-serif;
  }
  
  .container {
    /* border: 1px solid red; */
    width: 1000px;
    margin: 0 auto;
    display: inherit;
    justify-content: inherit;
    align-items: inherit;
    height: inherit;
    flex-wrap: inherit;
  }
